# %%
import numpy as np
import ROOT
ROOT.EnableImplicitMT(8)
ROOT.EnableThreadSafety()
# %jsroot on

# %%
# %pwd
# Out:
# '/home/ihor/CLionProjects/DMolybTarget/analysis'

# %%
root_files_dir = "/home/ihor/CLionProjects/DMolybTarget/root_files/"
root_file_name = "MolybdenumProtonBombardmentAllRuns.root"
tree_name = "neutrons_1"

# %%
root_file = ROOT.TFile.Open(root_files_dir + root_file_name)
if root_file.IsZombie():
    print("The input file does not filled with data")

# %%
root_file

# %%
dataframe = ROOT.RDataFrame(tree_name, root_files_dir + root_file_name)

# %%
dataframe

# %%
start, end = 0, 8
n_bins = 100
bin_width = (end - start) / n_bins
kinetic_energies = dataframe.Histo1D(("kinetic_energy", f"neutrons; E_kinetic [MeV]; Counts/{bin_width * 1e3} [keV]", n_bins, start, end) , "kinetic_energy")

# %%
c = ROOT.TCanvas()
kinetic_energies.Draw()
c.Draw()
# c.SaveAs("born_neutrons_ekin.svg")
# Out:
# <div id="root_plot_1738164043743" style="width: 700px; height: 500px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1738164043743(Core) {
# ...

# %%
dataframe1 = ROOT.RDataFrame("protons_vw_0", root_files_dir + root_file_name)

# %%
start, end = 10.9995, 11.0005
n_bins = 100
bin_width = round((end - start) / n_bins, 5)
kinetic_energies1 = dataframe1.Histo1D(("", f"Protons reaching the vacuum window; E_kinetic [MeV]; Counts/{bin_width * 1e3} [keV]", n_bins, start, end) , "kinetic_energy")

# %%
c1 = ROOT.TCanvas()
kinetic_energies1.Draw()
c1.Draw()
# c.SaveAs("protons_vw_0.svg")
# Out:
# <div id="root_plot_1738164045599" style="width: 700px; height: 500px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1738164045599(Core) {
# ...

# %%
dataframe1_1 = ROOT.RDataFrame("protons_vw_1", root_files_dir + root_file_name)
start, end = 10.7, 10.85
n_bins = 100
bin_width = round((end - start) / n_bins, 5)
kinetic_energies1_1 = dataframe1_1.Histo1D(("", f"Protons leaving the vacuum window; E_kinetic [MeV]; \
Counts/{bin_width * 1e3} [keV]", n_bins, start, end) , "kinetic_energy")
c1_1 = ROOT.TCanvas()
kinetic_energies1_1.Draw()
c1_1.Draw()
# c.SaveAs("protons_vw_0.svg")
# Out:
# <div id="root_plot_1738170941785" style="width: 700px; height: 500px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1738170941785(Core) {
# ...

# %%
dataframe2 = ROOT.RDataFrame("protons_sd0", root_files_dir + root_file_name)
start, end = 10.68, 10.85
n_bins = 100
bin_width = round((end - start) / n_bins, 5)
kinetic_energies2 = dataframe2.Histo1D(("", f"Protons reaching the molybdenum-100 tablet; E_kinetic [MeV]; Counts/{bin_width * 1e3} [keV]", n_bins, start, end) , "kinetic_energy")

# %%
c2 = ROOT.TCanvas()
kinetic_energies2.Draw()
c2.Draw()
# c.SaveAs("protons_vw_0.svg")
# Out:
# <div id="root_plot_1738164048670" style="width: 700px; height: 500px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1738164048670(Core) {
# ...

# %%
dataframe3 = ROOT.RDataFrame("protons_sd1", root_files_dir + root_file_name)
start, end = 10.68, 10.85
n_bins = 100
bin_width = round((end - start) / n_bins, 5)
kinetic_energies3 = dataframe3.Histo1D(("", f"Protons leaving the Al vacuum window; E_kinetic [MeV]; Counts/{bin_width * 1e3} [keV]", n_bins, start, end) , "kinetic_energy")

# %%
c3 = ROOT.TCanvas()
kinetic_energies3.Draw()
c3.Draw()
# c.SaveAs("protons_vw_0.svg")
# Out:
# <div id="root_plot_1738164073760" style="width: 700px; height: 500px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1738164073760(Core) {
# ...

# %%
type(kinetic_energies)
# Out:
# <class cppyy.gbl.ROOT.RDF.RResultPtr<TH1D> at 0x4855d730>

# %%
import numpy as np

# %%
bin_centers = []
bin_center_counts = []
bins = kinetic_energies.GetNbinsX()

for i in range(1, bins + 1):
    bin_center = kinetic_energies.GetBinCenter(i)
    # print(f"bin center: {bin_center}")
    bin_content = kinetic_energies.GetBinContent(i)
    # print(f"bin content: {bin_content}")
    bin_centers.append(bin_center)
    bin_center_counts.append(bin_content)

bin_centers = np.array(bin_centers)
bin_center_counts = np.array(bin_center_counts)

# %%
bin_centers
# Out:
# array([0.04, 0.12, 0.2 , 0.28, 0.36, 0.44, 0.52, 0.6 , 0.68, 0.76, 0.84,
#        0.92, 1.  , 1.08, 1.16, 1.24, 1.32, 1.4 , 1.48, 1.56, 1.64, 1.72,
#        1.8 , 1.88, 1.96, 2.04, 2.12, 2.2 , 2.28, 2.36, 2.44, 2.52, 2.6 ,
#        2.68, 2.76, 2.84, 2.92, 3.  , 3.08, 3.16, 3.24, 3.32, 3.4 , 3.48,
#        3.56, 3.64, 3.72, 3.8 , 3.88, 3.96, 4.04, 4.12, 4.2 , 4.28, 4.36,
#        4.44, 4.52, 4.6 , 4.68, 4.76, 4.84, 4.92, 5.  , 5.08, 5.16, 5.24,
#        5.32, 5.4 , 5.48, 5.56, 5.64, 5.72, 5.8 , 5.88, 5.96, 6.04, 6.12,
#        6.2 , 6.28, 6.36, 6.44, 6.52, 6.6 , 6.68, 6.76, 6.84, 6.92, 7.  ,
#        7.08, 7.16, 7.24, 7.32, 7.4 , 7.48, 7.56, 7.64, 7.72, 7.8 , 7.88,
#        7.96])

# %%
bin_center_counts
# Out:
# array([6.140e+02, 8.810e+02, 1.125e+03, 9.800e+02, 9.630e+02, 9.430e+02,
#        8.330e+02, 7.970e+02, 7.540e+02, 6.850e+02, 6.100e+02, 6.040e+02,
#        5.630e+02, 4.200e+02, 4.260e+02, 3.950e+02, 3.930e+02, 3.400e+02,
#        3.310e+02, 2.650e+02, 2.660e+02, 2.110e+02, 2.330e+02, 2.110e+02,
#        1.850e+02, 1.640e+02, 1.800e+02, 1.540e+02, 1.430e+02, 1.420e+02,
#        1.080e+02, 1.050e+02, 1.230e+02, 9.900e+01, 7.300e+01, 6.900e+01,
#        6.900e+01, 6.700e+01, 6.100e+01, 6.200e+01, 4.000e+01, 5.300e+01,
#        5.200e+01, 3.500e+01, 4.400e+01, 5.100e+01, 4.600e+01, 4.100e+01,
#        3.700e+01, 2.800e+01, 2.900e+01, 1.900e+01, 2.800e+01, 2.300e+01,
#        2.800e+01, 2.000e+01, 1.600e+01, 1.400e+01, 2.400e+01, 1.000e+01,
#        1.800e+01, 1.200e+01, 8.000e+00, 1.500e+01, 1.800e+01, 1.200e+01,
#        1.700e+01, 8.000e+00, 1.200e+01, 1.200e+01, 1.000e+01, 8.000e+00,
#        1.200e+01, 9.000e+00, 1.200e+01, 1.000e+01, 4.000e+00, 1.000e+01,
# ...

# %%
import iminuit as im
from iminuit import Minuit
from iminuit.cost import LeastSquares

bin_center_counts_error = np.sqrt(bin_center_counts)
bin_center_counts_error[bin_center_counts_error == 0] = 1

def exponential(x, A, lambda_):
    return A * np.exp(-x / lambda_)

least_squares = LeastSquares(bin_centers, bin_center_counts, bin_center_counts_error, model=exponential)
m = Minuit(least_squares, A = 25.e3, lambda_=1.5)
m.errordef = Minuit.LEAST_SQUARES
# Out:
# /home/ihor/CLionProjects/DMolybTarget/analysis/venv/lib/python3.12/site-packages/iminuit/minuit.py:139: ErrordefAlreadySetWarning: cost function has an errordef attribute equal to 1.0, you should not override this with Minuit.errordef
#   warnings.warn(msg, ErrordefAlreadySetWarning)

# %%
m.migrad()
# Out:
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                                Migrad                                   │
# ├──────────────────────────────────┬──────────────────────────────────────┤
# │ FCN = 760.6 (χ²/ndof = 7.8)      │              Nfcn = 66               │
# │ EDM = 0.000102 (Goal: 0.0002)    │                                      │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │          Valid Minimum           │   Below EDM threshold (goal x 10)    │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │      No parameters at limit      │           Below call limit           │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │             Hesse ok             │         Covariance accurate          │
# └──────────────────────────────────┴──────────────────────────────────────┘
# ...
